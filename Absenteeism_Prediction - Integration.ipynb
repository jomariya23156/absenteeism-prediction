# %%
from Absenteeism_module import *

# %%
model = AbsenteeismModel('pickle/absenteeism_model','pickle/custom_scaler')

# %%
model.load_and_clean_data('data/Absenteeism_new_data.csv')

# %%
model.data
# Out:
#     Reason_Group_1  Reason_Group_2  Reason_Group_3  Reason_Group_4     Month  \
# 0                0             0.0               0               1 -0.102784
# 1                1             0.0               0               0 -0.102784
# 2                0             0.0               0               1 -0.102784
# 3                0             0.0               0               1 -0.102784
# 4                1             0.0               0               0 -0.102784
# 5                1             0.0               0               0 -0.102784
# 6                1             0.0               0               0 -0.102784
# 7                0             0.0               0               1 -0.102784
# 8                0             0.0               0               1 -0.102784
# 9                1             0.0               0               0 -0.102784
# 10               0             0.0               0               1 -0.102784
# ...

# %%
model.predicted_outputs()
# Out:
#     Reason_Group_1  Reason_Group_2  Reason_Group_3  Reason_Group_4  Month  \
# 0                0             0.0               0               1      6
# 1                1             0.0               0               0      6
# 2                0             0.0               0               1      6
# 3                0             0.0               0               1      6
# 4                1             0.0               0               0      6
# 5                1             0.0               0               0      6
# 6                1             0.0               0               0      6
# 7                0             0.0               0               1      6
# 8                0             0.0               0               1      6
# 9                1             0.0               0               0      6
# 10               0             0.0               0               1      6
# 11               0             0.0               1               0      6
# ...

# %%
final_data = model.predicted_outputs()

# %%
final_data.shape
# Out:
# (40, 13)

# %%
import pymysql

# %%
conn = pymysql.connect(database = 'Predicted_outputs', user = 'root', password = '82546936')

# %%
cursor = conn.cursor()

# %%
cursor.execute('SELECT * FROM predicted_outputs;')
# Out:
# 0

# %%
insert_query = 'INSERT INTO predicted_outputs VALUES '

# %%
for row in range(final_data.shape[0]):
    
    insert_query += '('
    
    for column in final_data.columns.values:
        insert_query += str(final_data[column][row]) + ', '
    
    insert_query = insert_query[:-2] + '), '
    
insert_query = insert_query[:-2] + ';'

# %%
insert_query
# Out:
# 'INSERT INTO predicted_outputs VALUES (0, 0.0, 0, 1, 6, 179, 30, 19, 1, 0, 0, 0.12720268400193385, 0), (1, 0.0, 0, 0, 6, 361, 28, 27, 0, 1, 4, 0.8640291016335164, 1), (0, 0.0, 0, 1, 6, 155, 34, 25, 0, 2, 0, 0.26509643065626914, 0), (0, 0.0, 0, 1, 6, 179, 40, 22, 1, 2, 0, 0.20289411791455972, 0), (1, 0.0, 0, 0, 6, 155, 34, 25, 0, 2, 0, 0.7194128174545772, 1), (1, 0.0, 0, 0, 6, 225, 28, 24, 0, 1, 2, 0.7079782480120872, 1), (1, 0.0, 0, 0, 6, 118, 46, 25, 0, 2, 0, 0.5704693209939068, 1), (0, 0.0, 0, 1, 6, 179, 30, 19, 1, 0, 0, 0.12720268400193385, 0), (0, 0.0, 0, 1, 6, 118, 37, 28, 0, 0, 0, 0.13390924916629343, 0), (1, 0.0, 0, 0, 6, 118, 37, 28, 0, 0, 0, 0.523574790280447, 1), (0, 0.0, 0, 1, 6, 378, 36, 21, 0, 2, 4, 0.4374578443945194, 0), (0, 0.0, 1, 0, 6, 118, 50, 31, 0, 1, 0, 0.6396948957998115, 1), (0, 0.0, 1, 0, 6, 233, 31, 21, 1, 1, 8, 0.34474091170264454, 0), (0, 0.0, 0, 1, 6, 179, 30, 19, 1, 0, 0, 0.12720268400193385, 0), (0, 0.0, 0, 0, 6, 235, 48, 33, 0, 1, 5, 0.0774037831676201
# ...

# %%
cursor.execute(insert_query)
# Out:
# 40

# %%
conn.commit()

# %%
# verify
cursor.execute('SELECT * FROM predicted_outputs;')
# Out:
# 40

# %%
conn.close()

# %% [markdown]
# ## DONE!
